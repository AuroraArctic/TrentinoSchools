# %% [markdown]
# # 02-Geocoding
#
# After preparing Trentino school's data, we still need to gather the geographical coordinates of some schools. The reason why aprilascuola and vivoscuola dataset were merged is because schools' coordinates were present in aprilascuola's, which saves us from geocoding the address of over 700 schools.

# %%
from shapely.geometry import Point
import geopandas as gpd
import pandas as pd

# %%
# Data import
df = pd.read_pickle("../data/trentino/scuole.pkl")
df['CAP'] = df['CAP'].astype('string')

# %% [markdown]
# Let's convert the pickle file with schools details to a Geodataframe, considering lon and lat columns as its coordinates:

# %%
df = gpd.GeoDataFrame(df,
                      crs='EPSG:4326',
                      geometry=gpd.points_from_xy(df.lon, df.lat))

# %%
df.head()
# Out:
#   Id Istituto          Id                             Nome        lat  \
# 0  0220629599  0220629699  Settore Industria E Artigianato  46.369265
# 1  0221319599  0221319699                  Settore Servizi  46.310258
# 2  0222049599  0222049699  Settore Industria E Artigianato  46.176075
# 3  0222049599  0222049698                  Settore Servizi  46.176075
# 4  0221969599  0221969698  Settore Industria E Artigianato  46.287118
#
#          lon                                          Istituto  \
# 0  11.031445      Centro Formazione Professionale Enaip - Cles
# 1  10.745046    Centro Formazione Professionale Enaip - Ossana
# 2  11.833824  Centro Formazione Professionale Enaip - Primiero
# 3  11.833824  Centro Formazione Professionale Enaip - Primiero
# 4  11.511975    Centro Formazione Professionale Enaip - Tesero
#
#               Tipo Istituto   Gestione                   Indirizzo  \
# 0  Formazione professionale  Paritaria            Via Mitterer, 10
# 1  Formazione professionale  Paritaria         Via Di S Antonio, 1
# 2  Formazione professionale  Paritaria  Via Forno - Transacqua, 12
# 3  Formazione professionale  Paritaria  Via Forno - Transacqua, 12
# 4  Formazione professionale  Paritaria           Via Caltrezza, 13
#
#                               Comune     Telefono          Fax  \
# 0                               Cles  0463/421362  0463/421606
# 1                             Ossana  0463/751102  0463/751987
# 2  Primiero San Martino Di Castrozza  0439/762057  0439/762833
# 3  Primiero San Martino Di Castrozza  0439/762057  0439/762833
# 4                             Tesero  0462/813133  0462/813145
#
#         Email istituto          Email segreteria              Sito web  \
# 0      cfp.cles@pec.it      cfp.cles@enaip.tn.it  www.enaiptrentino.it
# 1    cfp.ossana@pec.it    cfp.ossana@enaip.tn.it  www.enaiptrentino.it
# 2  cfp.primiero@pec.it  cfp.primiero@enaip.tn.it  www.enaiptrentino.it
# 3  cfp.primiero@pec.it  cfp.primiero@enaip.tn.it  www.enaiptrentino.it
# 4    cfp.tesero@pec.it    cfp.tesero@enaip.tn.it  www.enaiptrentino.it
#
#   Codice MIUR    CAP                   geometry
# 0  TNFP251STA  38023  POINT (11.03144 46.36927)
# 1  TNFP252STA  38026  POINT (10.74505 46.31026)
# 2  TNFP253STA  38054  POINT (11.83382 46.17608)
# 3  TNFP253STA  38054  POINT (11.83382 46.17608)
# 4  TNFP254STA  38038  POINT (11.51198 46.28712)

# %% [markdown]
# If we consider the rows of the geodataframe were lat or lon are missing, we get the schools with missing coordinates, which are 308.

# %%
# Inspecting those schools with no coordinates
geocode_df = df[df['lat'].isna()]

# %%
len(geocode_df)
# Out:
# 308

# %% [markdown]
# In order to geocode the addresses into a shapely Point, we need to compose the complete address of the school. Let's start using nominatim provider on schools' name, address, CAP, municipality and Trento province.

# %%
# Create a complete address with street name and number, cap, municipality and province
tn_addresses = list(geocode_df['Nome']+", "+geocode_df['Indirizzo'].str.title() + ", " +
                    geocode_df['CAP']+", " + geocode_df['Comune'].str.title() + ", Trento")

# %%
# Geocoding with OpenStreetMap first, specifying the school to gather the exact position
geo_tn = gpd.tools.geocode(tn_addresses,
                           provider="nominatim",
                           user_agent="schools")

# %% [markdown]
# We can merge the dataset with missing values(i.e. `geocode_df`) with the one that detains geocoded coordinates (i.e. `geo_tn`). Whenever the address in `geo_tn` is null, the provider did not find any match with the concatenation of data we gave it. When merging `geocode_df` and `geo_tn`, we add an x-suffix to distinguish the common columns from one another. The merge is not based on some column, but on the row index, which should just concatenate horizontally the two datasets, providing missing geographical information to `geocode_df`.
#
# We will only consider the rows whose address found a match during the geocoding:

# %%
first = geocode_df.merge(geo_tn[~geo_tn['address'].isnull()],
                         left_index=True, right_index=True, suffixes=('x', ''))
first.drop(['geometryx'], axis=1, inplace=True)

# %%
first
# Out:
#     Id Istituto          Id  \
# 60   0221612005  0221612113
# 61   0221612005  0221613050
# 75   0221612907  0221612103
# 179  0222059599  0222059699
#
#                                                   Nome  lat  lon  \
# 60                  Scuola Primaria "La Vela" Rovereto  NaN  NaN
# 61   Scuola Secondaria Di Primo Grado "La Vela" Rov...  NaN  NaN
# 75   Scuola Primaria Arcivescovile Dame Inglesi Rov...  NaN  NaN
# 179                                    Settore Servizi  NaN  NaN
#
#                                               Istituto  \
# 60   Scuola Paritaria La Vela - Fondazione Famiglia...
# 61   Scuola Paritaria La Vela - Fondazione Famiglia...
# 75      Collegio Arcivescovile Dame Inglesi - Rovereto
# 179       Centro Formazione Professionale Upt - Trento
#
#                         Tipo Istituto   Gestione          Indirizzo    Comune  \
# 60                    Scuola Primaria  Paritaria    Via Saibanti, 6  Rovereto
# 61   Scuola Secondaria di Primo Grado  Paritaria    Via Saibanti, 6  Rovereto
# 75                    Scuola Primaria  Paritaria  Corso Bettini, 31  Rovereto
# 179          Formazione professionale  Paritaria    Via Borsieri, 2    Trento
#
#         Telefono          Fax                        Email istituto  \
# 60   0464/434047          NaN  segreteria@lavela.famigliamaterna.it
# 61   0464/435746          NaN       amministrazione@scuolalavela.it
# 75   0464/406000  0464/406077          collegioarcivescovile@pec.it
# 179  0461/239997  0461/260235                        cfp-upt@pec.it
#
#                          Email segreteria                    Sito web  \
# 60   segreteria@lavela.famigliamaterna.it       www.scuolaveronesi.it
# 61   segreteria@lavela.famigliamaterna.it       www.scuolaveronesi.it
# 75             lia@arcivescoviletrento.it  www.arcivescoviletrento.it
# 179            segreteria.sede@cfp-upt.it              www.cfp-upt.it
#
#     Codice MIUR    CAP                   geometry  \
# 60   TN1E00700T  38068  POINT (11.21984 45.99354)
# 61   TN1M00900P  38068  POINT (11.03047 46.23706)
# 75   TN1E006002  38068  POINT (11.06674 45.97856)
# 179  TNCF003001  38122  POINT (11.15177 46.06472)
#
#                                                address
# 60   Scuola dell'infanzia di Vattaro, 7, Via Giardi...
# 61   Scuola dell'Infanzia di Sporminore "Fratelli R...
# 75   scuola dell'infanzia di Cimone Mamma Teresa, 3...
# 179  Scuola dell'infanzia di Povo, 1, Via Panté, Pa...

# %% [markdown]
# We can replace geometry, lat and long columns values inside the original dataframe with the ones found by geocoding the addresses of schools with missing data.

# %%
df.loc[first.index, 'geometry'] = first['geometry']
df.loc[first.index, 'lat'] = [i.y for i in first['geometry']]
df.loc[first.index, 'lon'] = [i.x for i in first['geometry']]

# %% [markdown]
# Still, there are some schools missing. This time, the school's name is not considered in the address, hoping to find a match based on the mere address. The choice of recurring to schools names before was due to a more precise geocoding on OpenStreetMap, which sometimes may not find the right coordinates because schools denominations may differ for some characters between our dataset and data held in OSM. Also, let's try changing provider with Arcgis:

# %%
# Geocode with Arcgis the remaining addresses
geocode_df = df[df['lat'].isna()]
# Create a complete address with street name and number, cap, municipality and province
tn_addresses = list(geocode_df['Indirizzo'].str.title() + ", " +
                    geocode_df['CAP']+", " + geocode_df['Comune'].str.title() + ", Trento")

# %%
# Geocoding with Arcgis without school names
geo_tn = gpd.tools.geocode(tn_addresses,
                           provider="arcgis")

# %% [markdown]
# Still, we consider properly geocoded all those schools with no missing address or no address starting with its CAP (it means it has found the municipality, but not the specific location we're looking for). Notice that CAPs in Trentino all start with 38.

# %%
geo_tn.index = geocode_df.index
second = geocode_df.merge(geo_tn[(~geo_tn['address'].isnull()) &
                                 (~geo_tn['address'].str.startswith("38"))],
                          left_index=True, right_index=True, suffixes=('x', ''))
second.drop(['geometryx'], axis=1, inplace=True)

# %%
second
# Out:
#     Id Istituto          Id  \
# 11   0222059596  0222059696
# 13   0221619598  0221619698
# 16   0221539598  0221539698
# 74   0221612907  0221613006
# 76   0221612907  0221617115
# ..          ...         ...
# 719         NaN         NaN
# 720         NaN         NaN
# 721         NaN         NaN
# 722         NaN         NaN
# 723         NaN         NaN
#
#                                                   Nome  lat  lon  \
# 11                     Settore Industria E Artigianato  NaN  NaN
# 13                                     Settore Servizi  NaN  NaN
# 16                                     Settore Servizi  NaN  NaN
# 74   Scuola Secondaria Di Primo Grado Arcivescovile...  NaN  NaN
# 76   Liceo Linguistico Arcivescovile Dame Inglesi -...  NaN  NaN
# ..                                                 ...  ...  ...
# 719       Scuola Dell'Infanzia Di Trento Piedicastello  NaN  NaN
# 720  Scuola Dell'Infanzia Di Tierno Mori  "Il Giras...  NaN  NaN
# 721  Scuola Dell'Infanzia Di Pellizzano "Antonio Bo...  NaN  NaN
# 722                     Scuola Dell'Infanzia Di Tesero  NaN  NaN
# 723             Scuola Dell'Infanzia Di Villa Lagarina  NaN  NaN
#
#                                               Istituto  \
# 11   Centro Formazione Professionale Pavoniano Arti...
# 13   Centro Formazione Professionale Opera Armida B...
# 16          Centro Formazione Professionale Upt - Arco
# 74      Collegio Arcivescovile Dame Inglesi - Rovereto
# 76      Collegio Arcivescovile Dame Inglesi - Rovereto
# ..                                                 ...
# 719                      Circolo Di Coordinamento N. 5
# 720                      Circolo Di Coordinamento N. 9
# 721                     Circolo Di Coordinamento N. 11
# 722                     Scuola Dell'Infanzia Di Tesero
# 723             Scuola Dell'Infanzia Di Villa Lagarina
#
#                           Tipo Istituto   Gestione  \
# 11             Formazione professionale  Paritaria
# 13             Formazione professionale  Paritaria
# 16             Formazione professionale  Paritaria
# 74     Scuola Secondaria di Primo Grado  Paritaria
# 76   Scuola Secondaria di Secondo Grado  Paritaria
# ..                                  ...        ...
# 719                Scuola dell'Infanzia    Statale
# 720                Scuola dell'Infanzia    Statale
# 721                Scuola dell'Infanzia    Statale
# 722                Scuola dell'Infanzia  Paritaria
# 723                Scuola dell'Infanzia  Paritaria
#
#                       Indirizzo          Comune     Telefono          Fax  \
# 11           Piazza Di Fiera, 4          Trento  0461/270244  0461/270241
# 13              Via Setaioli, 5        Rovereto  0464/433771  0464/431711
# 16           Via Gazzoletti, 10            Arco  0464/556585  0464/556599
# 74            Corso Bettini, 31        Rovereto  0464/406000  0464/406077
# 76            Corso Bettini, 71        Rovereto  0464/406000  0464/406077
# ..                          ...             ...          ...          ...
# 719          Via Dos Trento, 86          Trento  0461/983539  0461/497257
# 720  Via della Cooperazione, 20            Mori  0464/917200  0464/493117
# 721        Via Dei Baschenis, 3      Pellizzano  335 1817040  0461/491940
# 722                 Via Fia, 20          Tesero  0462-813045          NaN
# 723    Via Monsignor Gosetti, 3  Villa Lagarina  0464-411101          NaN
#
#                                         Email istituto  \
# 11                                                 NaN
# 13              cfprovereto@pec.operaarmidabarelli.org
# 16                                      cfp-upt@pec.it
# 74                        collegioarcivescovile@pec.it
# 76                        collegioarcivescovile@pec.it
# ..                                                 ...
# 719  scuolainfanzia.piedicastello@scuole.provincia....
# 720       scuolainfanzia.tierno@scuole.provincia.tn.it
# 721   scuolainfanzia.pellizzano@scuole.provincia.tn.it
# 722                       tesero.presidente@fpsm.tn.it
# 723                villalagarina.presidente@fpsm.tn.it
#
#                             Email segreteria                        Sito web  \
# 11          scuolagrafica@artigianelli.tn.it  http://www.artigianelli.tn.it/
# 13        cfprovereto@operaarmidabarelli.org      www.operaarmidabarelli.org
# 16                segreteria.arco@cfp-upt.it      www.cfpupt.it/sede-di-arco
# 74                lia@arcivescoviletrento.it      www.arcivescoviletrento.it
# 76                lia@arcivescoviletrento.it      www.arcivescoviletrento.it
# ..                                       ...                             ...
# 719  circolo.coordinamento05@provincia.tn.it                             NaN
# 720  circolo.coordinamento09@provincia.tn.it                             NaN
# 721  circolo.coordinamento11@provincia.tn.it                             NaN
# 722             tesero.segretario@fpsm.tn.it                             NaN
# 723      villalagarina.segretario@fpsm.tn.it                             NaN
#
#     Codice MIUR    CAP                   geometry  \
# 11   TNCF004001  38122  POINT (11.12407 46.06439)
# 13   TNCF005001  38068  POINT (11.04219 45.88719)
# 16   TNFP261STA  38062  POINT (10.89410 45.91954)
# 74   TN1M00200X  38068  POINT (11.04390 45.89239)
# 76   TNPL005006  38068  POINT (11.04333 45.89687)
# ..          ...    ...                        ...
# 719         NaN  38122  POINT (11.11417 46.07174)
# 720         NaN  38065  POINT (10.97992 45.84566)
# 721         NaN  38020  POINT (10.75920 46.30963)
# 722         NaN  38038  POINT (11.51497 46.28956)
# 723         NaN  38060  POINT (11.03059 45.91760)
#
#                                                address
# 11                    Piazza di Fiera 4, 38122, Trento
# 13             Via Setaioli 5, 38068, Rovereto, Trento
# 16      Via Antonio Gazzoletti 10, 38062, Arco, Trento
# 74    Corso Angelo Bettini 31, 38068, Rovereto, Trento
# 76    Corso Angelo Bettini 71, 38068, Rovereto, Trento
# ..                                                 ...
# 719                   Via Dos Trento 86, 38121, Trento
# 720     Via della Cooperazione 20, 38065, Mori, Trento
# 721     Via dei Baschenis 3, 38020, Pellizzano, Trento
# 722                  Via Fia 20, 38038, Tesero, Trento
# 723  Via Monsignor Giovanni Osetti 3, 38060, Villa ...
#
# [280 rows x 19 columns]

# %% [markdown]
# We can replace geometry, lat and long columns values inside the original dataframe with the ones found by geocoding the addresses of schools with missing data.

# %%
df.loc[second.index, 'geometry'] = second['geometry']
df.loc[second.index, 'lat'] = [i.y for i in second['geometry']]
df.loc[second.index, 'lon'] = [i.x for i in second['geometry']]

# %%
geocode_df = df[df['lat'].isna()]

# %%
len(geocode_df)
# Out:
# 24

# %% [markdown]
# Still, 24 schools' coords are missing. Let's retry without the CAP column and by using nominatim provider:

# %%
tn_addresses = list(geocode_df['Indirizzo'].str.title() + ", " +
                    geocode_df['Comune'].str.title() + ", Trento")

# %%
# Geocoding with OpenStreetMap without school names
geo_tn = gpd.tools.geocode(tn_addresses,
                           provider="nominatim",
                           user_agent="schools")

# %% [markdown]
# As before, let's remove the non-matching addresses and merge the missing schools' data with the matching coordinates found:

# %%
geo_tn.index = geocode_df.index
third = geocode_df.merge(geo_tn[~geo_tn['address'].isnull()],
                          left_index=True, right_index=True, suffixes=('x', ''))
third.drop(['geometryx'], axis=1, inplace=True)

# %%
df.loc[third.index, 'geometry'] = third['geometry']
df.loc[third.index, 'lat'] = [i.y for i in third['geometry']]
df.loc[third.index, 'lon'] = [i.x for i in third['geometry']]

# %% [markdown]
# Despite the three geocoding with different combinations of fields to create the address and different providers, some schools seem they don't want to be found 😅. Some of these schools were searched and inserted inside OpenStreetMap, but still the provider has some difficulties in finding these schools.

# %%
# Search for None objects remaining
geocode_df = df[df['lat'].isna()]

# %%
geocode_df
# Out:
#     Id Istituto   Id                                               Nome  lat  \
# 525         NaN  NaN  Scuola Dell'Infanzia Di Pera Di Fassa "Don Edy...  NaN
# 545         NaN  NaN                     Scuola Dell'Infanzia Di Cimego  NaN
# 571         NaN  NaN           Scuola Dell'Infanzia Di Molina Di  Ledro  NaN
# 605         NaN  NaN                Scuola Dell'Infanzia Di Ponte Arche  NaN
# 626         NaN  NaN       Scuola Dell'Infanzia Di Madonna Di Campiglio  NaN
# 659         NaN  NaN                 Scuola Dell'Infanzia Di Serravalle  NaN
# 666         NaN  NaN           Scuola Dell'Infanzia Di S. Croce Bleggio  NaN
# 668         NaN  NaN              Scuola Dell'Infanzia Di Vigo Di Fassa  NaN
#
#      lon                                           Istituto  \
# 525  NaN  Coordinamento Pedagogico Scuole Provinciali De...
# 545  NaN                      Circolo Di Coordinamento N. 8
# 571  NaN            Scuola Dell'Infanzia Di Molina Di Ledro
# 605  NaN                Scuola Dell'Infanzia Di Ponte Arche
# 626  NaN       Scuola Dell'Infanzia Di Madonna Di Campiglio
# 659  NaN                 Scuola Dell'Infanzia Di Serravalle
# 666  NaN           Scuola Dell'Infanzia Di S. Croce Bleggio
# 668  NaN              Scuola Dell'Infanzia Di Vigo Di Fassa
#
#             Tipo Istituto   Gestione  \
# 525  Scuola dell'Infanzia    Statale
# 545  Scuola dell'Infanzia    Statale
# 571  Scuola dell'Infanzia  Paritaria
# 605  Scuola dell'Infanzia  Paritaria
# 626  Scuola dell'Infanzia  Paritaria
# 659  Scuola dell'Infanzia  Paritaria
# 666  Scuola dell'Infanzia  Paritaria
# 668  Scuola dell'Infanzia  Paritaria
#
#                                              Indirizzo  \
# 525  Piaza don Giuseppe Antonio Vian - Pozza di Fas...
# 545                     Via don Bertolasi - Cimego, 64
# 571                  Via Sartori - Molina di Ledro, 25
# 605  Via S Giovanni Bosco - Ponte Arche - Bleggio I...
# 626            Via Serafini - Madonna di Campiglio, 13
# 659                Via Ingenger Tomasi - Serravalle, 5
# 666       Frazione Santa Croce di Bleggio Inferiore, 7
# 668      Strada Giuseppe Soraperra - Pozza di Fassa, 4
#
#                               Comune     Telefono          Fax  \
# 525  San Giovanni Di Fassa - Sen Jan  0462/764828  0462/760001
# 545                     Borgo Chiese  0465/621567  0461/493389
# 571                            Ledro  0464-508477          NaN
# 605                     Comano Terme  0465-702422          NaN
# 626                        Tre Ville  0465-442779  0465 442779
# 659                              Ala  0464-696304          NaN
# 666                     Comano Terme  0465-779900          NaN
# 668  San Giovanni Di Fassa - Sen Jan  0462-763194          NaN
#
#                                    Email istituto  \
# 525    scuolainfanzia.pera@scuole.provincia.tn.it
# 545  scuolainfanzia.cimego@scuole.provincia.tn.it
# 571            molina.ledro.presidente@fpsm.tn.it
# 605             ponte.arche.presidente@fpsm.tn.it
# 626       madonna.campiglio.segretario@fpsm.tn.it
# 659              serravalle.presidente@fpsm.tn.it
# 666                 s.croce.presidente@fpsm.tn.it
# 668              vigo.fassa.presidente@fpsm.tn.it
#
#                                Email segreteria Sito web Codice MIUR    CAP  \
# 525  coordinamento.scuoleladine@provincia.tn.it      NaN         NaN  38036
# 545     circolo.coordinamento08@provincia.tn.it      NaN         NaN  38083
# 571          molina.ledro.segretario@fpsm.tn.it      NaN         NaN  38067
# 605           ponte.arche.segretario@fpsm.tn.it      NaN         NaN  38070
# 626     madonna.campiglio.segretario@fpsm.tn.it      NaN         NaN  38070
# 659            serravalle.segretario@fpsm.tn.it      NaN         NaN  38061
# 666               s.croce.segretario@fpsm.tn.it      NaN         NaN  38070
# 668            vigo.fassa.segretario@fpsm.tn.it      NaN         NaN  38036
#
#         geometry
# 525  POINT EMPTY
# 545  POINT EMPTY
# 571  POINT EMPTY
# 605  POINT EMPTY
# 626  POINT EMPTY
# 659  POINT EMPTY
# 666  POINT EMPTY
# 668  POINT EMPTY

# %% [markdown]
# Considering that the remaining schools are 8, their coordinates are inserted manually.

# %%
# Manually inserting coordinates
geocode_df[['lat','lon']] = [[46.43982, 11.69179],
                             [45.91263, 10.61412],
                             [45.87063, 10.77462],
                             [46.0354, 10.87076],
                             [46.22257, 10.82716],
                             [45.81072, 11.01411],
                             [46.02616, 10.83888],
                             [46.42304, 11.68182]]
geocode_df['geometry'] = geometry = [Point(xy) for xy in zip(geocode_df['lon'], geocode_df['lat'])]
# Out:
# C:\Users\auror\anaconda3\envs\geospatial\lib\site-packages\geopandas\geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\auror\anaconda3\envs\geospatial\lib\site-packages\geopandas\geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# For the last time, let's replace missing values with the ones manually inserted:

# %%
df.loc[geocode_df.index, 'geometry'] = geocode_df['geometry']
df.loc[geocode_df.index, 'lat'] = [i.y for i in geocode_df['geometry']]
df.loc[geocode_df.index, 'lon'] = [i.x for i in geocode_df['geometry']]

# %% [markdown]
# We can check if there are missing shapely Points by calling `df.explore()`, since it will not execute if some None points are found. Also, we can inspect schools on the map and see if some points are outside the perimetered territory of Trentino.

# %%
# Check if there are None points
df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_527ed6b88f734bd9acec84da493a6ce8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# In the end, we can save these data, both as geojson and shapefile (which will be necessary for the R analysis).

# %%
# Saving coordinates in GeoJSON
df.to_crs(4326).to_file("../data/trentino/schools/schools.geojson", index=False)

# Saving schools as shapefile
df = gpd.read_file("../data/trentino/schools/schools.geojson")
df.to_file("../data/Trentino/schools", driver='ESRI Shapefile')
# Out:
# C:\Users\auror\AppData\Local\Temp/ipykernel_35376/3060867726.py:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   df.to_file("../data/Trentino/schools", driver='ESRI Shapefile')
